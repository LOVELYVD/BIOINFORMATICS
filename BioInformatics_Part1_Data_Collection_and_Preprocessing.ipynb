# %% [markdown]
# <a href="https://colab.research.google.com/github/LOVELYVD/BIOINFORMATICS/blob/main/BioInformatics_Part1_Data_Collection_and_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**
#
#  we will be building a machine learning model using the ChEMBL bioactivity data.
#
#
# 1.
# *   Downloaded dataset of biological activity from ChEMBL Dataset.
# *  Dataset contains molecule names and corresponding smiles notations          - information about chemical structure
# *  Dataset also contains info about  IC50-Bioactivity class label:inactive,  active,intermediate
# 2. Combine DataFrame
# 3. Write the output file to a preprocessed csv file

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.7/dist-packages (0.10.7)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (2.23.0)
# Requirement already satisfied: easydict in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (1.24.3)
# Requirement already satisfied: requests-cache~=0.7.0 in /usr/local/lib/python3.7/dist-packages (from chembl_webresource_client) (0.7.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2.10)
# Requirement already satisfied: attrs<22.0,>=21.2 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (21.2.0)
# Requirement already satisfied: pyyaml>=5.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (6.0)
# Requirement already satisfied: itsdangerous>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (2.0.1)
# Requirement already satisfied: url-normalize<2.0,>=1.4 in /usr/local/lib/python3.7/dist-packages (from requests-cache~=0.7.0->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from url-normalize<2.0,>=1.4->requests-cache~=0.7.0->chembl_webresource_client) (1.15.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  ...   tax_id
# 0                                                 []  ...    11119
# 1                                                 []  ...   227859
# 2                                                 []  ...    12663
# 3                                                 []  ...    11137
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...  ...   227859
# 5                                                 []  ...  1335626
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...  ...   227859
# 7                                                 []  ...  2697049
#
# [8 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[5]
selected_target
# Out:
# 'CHEMBL4296578'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id  ... upper_value value
# 0             None     18893658  ...        None  0.77
# 1             None     18893659  ...        None  25.0
# 2             None     18893660  ...        None  25.0
#
# [3 rows x 45 columns]

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data.csv', index=False)

# %% [markdown]
# ## **Copying files to Google Drive**

# %% [markdown]
# Firstly, we need to mount the Google Drive into Colab so that we can have access to our Google adrive from within Colab.

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# Next, we create a **data** folder in our **Colab Notebooks** folder on Google Drive.

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data2"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data2’: File exists

# %%
! cp bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# -rw------- 1 root root 16910 Dec 10 10:34 '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# Let's see the CSV files that we have so far.

# %%
! ls
# Out:
# bioactivity_data.csv  gdrive  sample_data

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
! head bioactivity_data.csv
# Out:
# activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,18893658,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(NC(C)C)[nH]c2c(C(F)(F)F)cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4471536,,CHEMBL4471536,6.11,False,http://www.openphacts.org/units/Nanomolar,3152357,=,1,True,=,,IC50,nM,,770.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.77
# ,18893659,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(NC(C)C)[nH]c2c(C(C)C)cccc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4472908,,CHEMBL4472908,,False,http://www.openphacts.org/units/Nanomolar,3152358,>,1,True,>,,IC50,nM,,25000.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,25.0
# ,18893660,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(NC(C)C)[nH]c2c(C)cc(C)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4580358,,CHEMBL4580358,,False,http://www.openphacts.org/units/Nanomolar,3152359,>,1,True,>,,IC50,nM,,25000.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,25.0
# ,18893661,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(C)Nc1[nH]c2c(C(F)(F)F)cc(Cl)cc2c(=O)c1C(=O)c1ccccc1,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4531009,,CHEMBL4531009,,False,http://www.openphacts.org/units/Nanomolar,3152360,>,1,True,>,,IC50,nM,,25000.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,25.0
# ,18893662,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(C(F)(F)F)cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4554138,,CHEMBL4554138,6.82,False,http://www.openphacts.org/units/Nanomolar,3152361,=,1,True,=,,IC50,nM,,150.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.15
# ,18893663,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(F)cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4530008,,CHEMBL4530008,6.01,False,http://www.openphacts.org/units/Nanomolar,3152356,=,1,True,=,,IC50,nM,,980.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.98
# ,18893664,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c([N+](=O)[O-])cc(Cl)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4573119,,CHEMBL4573119,5.94,False,http://www.openphacts.org/units/Nanomolar,3152362,=,1,True,=,,IC50,nM,,1160.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,1.16
# ,18893665,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(F)cc(F)cc2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4554248,,CHEMBL4554248,5.97,False,http://www.openphacts.org/units/Nanomolar,3152363,=,1,True,=,,IC50,nM,,1060.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,1.06
# ,18893666,[],CHEMBL4315144,Antiviral activity against MERS-CoV KOR/KNIH/002_05_2015 infected in African green monkey Vero cells expressing viral spike protein by immunofluorescence assay,F,,,BAO_0000190,BAO_0000218,organism-based format,CC(=O)c1c(Nc2ccc(F)cc2F)[nH]c2c(Cl)cc(Cl)c(Cl)c2c1=O,,,CHEMBL4311996,Bioorg Med Chem Lett,2019,,CHEMBL4565616,,CHEMBL4565616,6.54,False,http://www.openphacts.org/units/Nanomolar,3152364,=,1,True,=,,IC50,nM,,290.0,CHEMBL4296578,Middle East respiratory syndrome-related coronavirus,Middle East respiratory syndrome-related coronavirus,1335626,,,IC50,uM,UO_0000065,,0.29

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2
# Out:
#    activity_comment  activity_id  ... upper_value  value
# 0              None     18893658  ...        None   0.77
# 1              None     18893659  ...        None   25.0
# 2              None     18893660  ...        None   25.0
# 3              None     18893661  ...        None   25.0
# 4              None     18893662  ...        None   0.15
# 5              None     18893663  ...        None   0.98
# 6              None     18893664  ...        None   1.16
# 7              None     18893665  ...        None   1.06
# 8              None     18893666  ...        None   0.29
# 9              None     18893667  ...        None   25.0
# 10             None     18893668  ...        None   25.0
# 11             None     18893669  ...        None   25.0
# 12             None     18893670  ...        None    7.8
# 13             None     18893671  ...        None    5.9
# 14             None     18893672  ...        None   17.6
# 15             None     18893673  ...        None   25.0
# 16             None     18893674  ...        None   25.0
# 17             None     18893675  ...        None   25.0
# 18             None     18893676  ...        None   1.13
# 19             None     18893677  ...        None   1.44
# 20             None     18893678  ...        None   0.53
# 21             None     18893679  ...        None  0.086
# 22             None     18893680  ...        None   0.79
# 23             None     18893681  ...        None    0.1
# 24             None     18893682  ...        None  0.166
# 25             None     18893683  ...        None  0.129
# 26             None     18893684  ...        None   0.13
#
# [27 rows x 45 columns]

# %% [markdown]
# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#    molecule_chembl_id  ... standard_value
# 0       CHEMBL4471536  ...          770.0
# 1       CHEMBL4472908  ...        25000.0
# 2       CHEMBL4580358  ...        25000.0
# 3       CHEMBL4531009  ...        25000.0
# 4       CHEMBL4554138  ...          150.0
# 5       CHEMBL4530008  ...          980.0
# 6       CHEMBL4573119  ...         1160.0
# 7       CHEMBL4554248  ...         1060.0
# 8       CHEMBL4565616  ...          290.0
# 9       CHEMBL4460922  ...        25000.0
# 10      CHEMBL4469302  ...        25000.0
# 11      CHEMBL4451470  ...        25000.0
# 12      CHEMBL4453755  ...         7800.0
# 13      CHEMBL4548966  ...         5900.0
# 14      CHEMBL4452847  ...        17600.0
# 15      CHEMBL4578865  ...        25000.0
# 16      CHEMBL4561863  ...        25000.0
# 17      CHEMBL4455226  ...        25000.0
# 18      CHEMBL4444279  ...         1130.0
# 19      CHEMBL4454132  ...         1440.0
# 20      CHEMBL4444752  ...          530.0
# 21      CHEMBL4526734  ...           86.0
# 22      CHEMBL4463570  ...          790.0
# 23      CHEMBL4572255  ...          100.0
# 24      CHEMBL4558866  ...          166.0
# 25      CHEMBL4459172  ...          129.0
# 26      CHEMBL4545243  ...          130.0
#
# [27 rows x 4 columns]

# %% [markdown]
# ### **Alternative method**

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df3 = df2[selection]
df3
# Out:
#    molecule_chembl_id  ... standard_value
# 0       CHEMBL4471536  ...          770.0
# 1       CHEMBL4472908  ...        25000.0
# 2       CHEMBL4580358  ...        25000.0
# 3       CHEMBL4531009  ...        25000.0
# 4       CHEMBL4554138  ...          150.0
# 5       CHEMBL4530008  ...          980.0
# 6       CHEMBL4573119  ...         1160.0
# 7       CHEMBL4554248  ...         1060.0
# 8       CHEMBL4565616  ...          290.0
# 9       CHEMBL4460922  ...        25000.0
# 10      CHEMBL4469302  ...        25000.0
# 11      CHEMBL4451470  ...        25000.0
# 12      CHEMBL4453755  ...         7800.0
# 13      CHEMBL4548966  ...         5900.0
# 14      CHEMBL4452847  ...        17600.0
# 15      CHEMBL4578865  ...        25000.0
# 16      CHEMBL4561863  ...        25000.0
# 17      CHEMBL4455226  ...        25000.0
# 18      CHEMBL4444279  ...         1130.0
# 19      CHEMBL4454132  ...         1440.0
# 20      CHEMBL4444752  ...          530.0
# 21      CHEMBL4526734  ...           86.0
# 22      CHEMBL4463570  ...          790.0
# 23      CHEMBL4572255  ...          100.0
# 24      CHEMBL4558866  ...          166.0
# 25      CHEMBL4459172  ...          129.0
# 26      CHEMBL4545243  ...          130.0
#
# [27 rows x 3 columns]

# %%
pd.concat([df3,pd.Series(bioactivity_class)], axis=1)
# Out:
#    molecule_chembl_id  ...             0
# 0       CHEMBL4471536  ...        active
# 1       CHEMBL4472908  ...      inactive
# 2       CHEMBL4580358  ...      inactive
# 3       CHEMBL4531009  ...      inactive
# 4       CHEMBL4554138  ...        active
# 5       CHEMBL4530008  ...        active
# 6       CHEMBL4573119  ...  intermediate
# 7       CHEMBL4554248  ...  intermediate
# 8       CHEMBL4565616  ...        active
# 9       CHEMBL4460922  ...      inactive
# 10      CHEMBL4469302  ...      inactive
# 11      CHEMBL4451470  ...      inactive
# 12      CHEMBL4453755  ...  intermediate
# 13      CHEMBL4548966  ...  intermediate
# 14      CHEMBL4452847  ...      inactive
# 15      CHEMBL4578865  ...      inactive
# 16      CHEMBL4561863  ...      inactive
# 17      CHEMBL4455226  ...      inactive
# 18      CHEMBL4444279  ...  intermediate
# 19      CHEMBL4454132  ...  intermediate
# 20      CHEMBL4444752  ...        active
# 21      CHEMBL4526734  ...        active
# 22      CHEMBL4463570  ...        active
# 23      CHEMBL4572255  ...        active
# 24      CHEMBL4558866  ...        active
# 25      CHEMBL4459172  ...        active
# 26      CHEMBL4545243  ...        active
#
# [27 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('bioactivity_preprocessed_data.csv', index=False)

# %%
! ls -l
# Out:
# total 32
# -rw-r--r-- 1 root root 16910 Dec 10 10:34 bioactivity_data.csv
# -rw-r--r-- 1 root root  1955 Dec 10 10:34 bioactivity_preprocessed_data.csv
# drwx------ 5 root root  4096 Dec 10 10:34 gdrive
# drwxr-xr-x 1 root root  4096 Dec  3 14:33 sample_data

# %% [markdown]
# Let's copy to the Google Drive

# %%
! cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# '/content/gdrive/My Drive/Colab Notebooks/data'

# %% [markdown]
# ---
